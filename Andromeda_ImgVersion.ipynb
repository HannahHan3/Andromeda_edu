# %% [markdown]
# # Andromeda with Image Data in Jupyter

# %%
# %matplotlib widget
from utils import *
# Out:
# 39 images loaded
# <style>.container { width:95% !important; }</style>
# <style>.output_result { max-width:100% !important; }</style>
# <style>
#     .widget-label { min-width: 20ex !important; }
# </style>

# %%
plot_ax = create_plot(df_2D, imgDisplaySize)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
size_slider = create_size_slider(imgDisplaySize)
sliders = create_sliders(weights)
size_apply_button = create_size_slider_button(size_slider,plot_ax)
# Out:
# FloatSlider(value=1e-05, continuous_update=False, description='Eccentricity', layout=Layout(width='100%'), max…
# FloatSlider(value=1e-05, continuous_update=False, description='Aspect Ratio', layout=Layout(width='100%'), max…
# FloatSlider(value=1e-05, continuous_update=False, description='Elongation', layout=Layout(width='100%'), max=0…
# FloatSlider(value=1e-05, continuous_update=False, description='Solidity', layout=Layout(width='100%'), max=0.9…
# FloatSlider(value=1e-05, continuous_update=False, description='Stochastic Convexity', layout=Layout(width='100…
# FloatSlider(value=1e-05, continuous_update=False, description='Isoperimetric Factor', layout=Layout(width='100…
# FloatSlider(value=1e-05, continuous_update=False, description='Maximal Indentation Depth', layout=Layout(width…
# FloatSlider(value=1e-05, continuous_update=False, description='Lobedness', layout=Layout(width='100%'), max=0.…
# FloatSlider(value=1e-05, continuous_update=False, description='Average Intensity', layout=Layout(width='100%')…
# FloatSlider(value=1e-05, continuous_update=False, description='Average Contrast', layout=Layout(width='100%'),…
# FloatSlider(value=1e-05, continuous_update=False, description='Smoothness', layout=Layout(width='100%'), max=0…
# FloatSlider(value=1e-05, continuous_update=False, description='Third Moment', layout=Layout(width='100%'), max…
# FloatSlider(value=1e-05, continuous_update=False, description='Uniformity', layout=Layout(width='100%'), max=0…
# FloatSlider(value=1e-05, continuous_update=False, description='Entropy', layout=Layout(width='100%'), max=0.99…

# %%
point_attribute = create_checkbox(size_slider, plot_ax)
inverse_button, copy_button = create_inverse_button(plot_ax, size_slider, sliders)
display(widgets.HBox([inverse_button, copy_button,create_reset_buttons(plot_ax, size_slider, sliders),
                      create_slider_buttons(sliders,size_slider, plot_ax)]))
display(widgets.HBox([size_slider,size_apply_button]))
# Out:
# interactive(children=(Checkbox(value=False, description='Toggle Titles', indent=False, layout=Layout(height='2…
# interactive(children=(Checkbox(value=True, description='Toggle Images', indent=False, layout=Layout(height='20…
# HBox(children=(Button(description='Learn New Weights', style=ButtonStyle(button_color='darkseagreen')), Button…
# HBox(children=(FloatSlider(value=0.4, continuous_update=False, description='Adjust image size', max=1.0, reado…
